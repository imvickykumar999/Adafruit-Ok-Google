# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Vicky\Downloads\2021 Calendar - 2021.csv')

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN   JANUARY         NaN        NaN        NaN        NaN
# 1          NaN          S          M          T          W          T
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN          3          4          5          6          7
# 4          NaN         10         11         12         13         14
# 5          NaN         17         18         19         20         21
# 6          NaN         24         25         26         27         28
# 7          NaN         31        NaN        NaN        NaN        NaN
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 9          NaN     APRIL         NaN        NaN        NaN        NaN
# 10         NaN          S          M          T          W          T
# 11         NaN        NaN        NaN        NaN        NaN          1
# ...
